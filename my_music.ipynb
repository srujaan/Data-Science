# %%
import pandas as pd

# %%
read_file = pd.read_csv('/home/srujan/Desktop/ds_edx/srujaan-3qmsB1xMGKSMxoNhlq2R5X.csv')

# %%
read_file
# Out:
#      energy  liveness    tempo  speechiness  acousticness  instrumentalness  \
# 0     0.532    0.0925  136.571       0.0286       0.43200          0.000006
# 1     0.759    0.2310  179.904       0.0431       0.05550          0.000000
# 2     0.776    0.3000   77.987       0.0459       0.05720          0.000008
# 3     0.715    0.0942  155.925       0.0362       0.00125          0.000008
# 4     0.609    0.1870  135.671       0.0339       0.42000          0.000000
# ..      ...       ...      ...          ...           ...               ...
# 230   0.699    0.3850   84.016       0.0566       0.14900          0.006790
# 231   0.736    0.3470  100.030       0.0450       0.01650          0.000000
# 232   0.563    0.1790  100.017       0.1340       0.62100          0.000000
# 233   0.771    0.1140  120.014       0.0509       0.12200          0.000000
# 234   0.396    0.1050   90.024       0.0286       0.08410          0.000036
#
# ...

# %%
read_file.describe()
# Out:
#            energy    liveness       tempo  speechiness  acousticness  \
# count  235.000000  235.000000  235.000000   235.000000    235.000000
# mean     0.700881    0.167950  123.683268     0.057567      0.142036
# std      0.181633    0.125046   30.093087     0.045255      0.209577
# min      0.121000    0.029600   57.860000     0.023300      0.000033
# 25%      0.588000    0.092200  100.025000     0.031250      0.010250
# 50%      0.719000    0.118000  121.070000     0.041400      0.048500
# 75%      0.840000    0.197000  142.460500     0.059750      0.184000
# max      0.978000    0.832000  195.881000     0.280000      0.910000
#
#        instrumentalness  time_signature  danceability         key  \
# count        235.000000      235.000000    235.000000  235.000000
# mean           0.021897        3.961702      0.538698    4.655319
# std            0.102024        0.232557      0.143604    3.545239
# min            0.000000        3.000000      0.163000    0.000000
# ...

# %%
read_file.columns
# Out:
# Index(['energy', 'liveness', 'tempo', 'speechiness', 'acousticness',
#        'instrumentalness', 'time_signature', 'danceability', 'key',
#        'duration_ms', 'loudness', 'valence', 'mode', 'type', 'uri'],
#       dtype='object')

# %%
req_fields = pd.DataFrame(read_file, columns=['energy', 'liveness','valence', 'speechiness', 'acousticness', 'instrumentalness', 'danceability'])
avg = req_fields.mean()

# %%
avg
# Out:
# energy              0.700881
# liveness            0.167950
# valence             0.443874
# speechiness         0.057567
# acousticness        0.142036
# instrumentalness    0.021897
# danceability        0.538698
# dtype: float64

# %%
# %matplotlib inline
avg.plot(kind='bar',figsize=(15,10))

# %%
avg.plot(kind='pie',figsize=(20, 13))

# %%
standard_deviation = req_fields.std()
standard_deviation
# Out:
# energy              0.181633
# liveness            0.125046
# valence             0.226688
# speechiness         0.045255
# acousticness        0.209577
# instrumentalness    0.102024
# danceability        0.143604
# dtype: float64

# %%
standard_deviation.plot(kind='bar',figsize=(15,10))

# %%
standard_deviation.plot(kind='pie',figsize=(15,10))
