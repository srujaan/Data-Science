# %%
import pandas as pd

# %%
read_data = pd.read_csv('/home/srujan/Downloads/pokemon/Pokemon.csv',sep=',')

# %%
read_data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
test = read_data['Type 1'].str.contains('Grass')
read_data[test]
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %%
read_data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
t = pd.DataFrame(read_data)

# %%
t.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
t.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
required_fields=pd.DataFrame(t,columns=['Name', 'Total', 'HP', 'Speed', 'Generation'])
required_fields.head()
# Out:
#                     Name  Total  HP  Speed  Generation
# 0              Bulbasaur    318  45     45           1
# 1                Ivysaur    405  60     60           1
# 2               Venusaur    525  80     80           1
# 3  VenusaurMega Venusaur    625  80     80           1
# 4             Charmander    309  39     65           1

# %%
top_speed = read_data['Speed'].max()

# %%
top_speed
# Out:
# 180

# %%
read_data['Total'].describe()
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
read_data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
read_data.shape
# Out:
# (800, 13)

# %%
read_data.isnull().any()
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2         True
# Total         False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %%
read_data = read_data.dropna()

# %%
read_data.isnull().any()
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# Total         False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %%
read_data.shape
# Out:
# (414, 13)

# %%
# %matplotlib inline
read_data.hist(column='Total', figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9a9eebf650>]],
#       dtype=object)

# %%
read_data.boxplot(column='Total', figsize=(15,10))

# %%
read_data['Type 1'].head()
# Out:
# 0    Grass
# 1    Grass
# 2    Grass
# 3    Grass
# 6     Fire
# Name: Type 1, dtype: object

# %%
read_data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 6      109       85    100           1      False

# %%
total_type1 = read_data['Type 1'].value_counts()
total_type1
# Out:
# Water       53
# Bug         52
# Grass       37
# Normal      37
# Rock        35
# Fire        24
# Steel       22
# Ghost       22
# Dragon      21
# Dark        21
# Psychic     19
# Ground      19
# Electric    17
# Poison      13
# Ice         11
# Fighting     7
# Fairy        2
# Flying       2
# Name: Type 1, dtype: int64

# %%
total_type2 = read_data['Type 2'].value_counts()
total_type2
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Ice         14
# Water       14
# Rock        14
# Ghost       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
total_type1.plot(kind='pie', figsize=(23,18))

# %%
total_type2.plot(kind='pie',figsize=(15,10))

# %%
top_pokemons = read_data['Name']
top_pokemons.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 6                Charizard
# Name: Name, dtype: object

# %%
power = read_data['Name']
high_to_low = pd.DataFrame(sorted(power,reverse=True))
#read_data[power].head()

# %%
read_data[['Name', 'Total']].head()
# Out:
#                     Name  Total
# 0              Bulbasaur    318
# 1                Ivysaur    405
# 2               Venusaur    525
# 3  VenusaurMega Venusaur    625
# 6              Charizard    534

# %%
high_to_low.head()
# Out:
#                   0
# 0  Zygarde50% Forme
# 1          Zweilous
# 2             Zubat
# 3            Zekrom
# 4            Zapdos

# %%
total_power = pd.DataFrame(read_data[['Name', 'Total']]).sort_values(by='Total',ascending=False)
total_power.head(20)
# Out:
#                         Name  Total
# 426    RayquazaMega Rayquaza    780
# 163      MewtwoMega Mewtwo X    780
# 424    GroudonPrimal Groudon    770
# 494    GarchompMega Garchomp    700
# 413  MetagrossMega Metagross    700
# 711       KyuremBlack Kyurem    700
# 712       KyuremWhite Kyurem    700
# 418        LatiasMega Latias    700
# 420        LatiosMega Latios    700
# 409  SalamenceMega Salamence    700
# 796      DiancieMega Diancie    700
# 268  TyranitarMega Tyranitar    700
# 793                  Yveltal    680
# 545     GiratinaOrigin Forme    680
# 270                    Ho-oh    680
# 269                    Lugia    680
# 425                 Rayquaza    680
# 798       HoopaHoopa Unbound    680
# 707                   Zekrom    680
# 706                 Reshiram    680

# %%
name_count = total_power['Name'].value_counts()
name_count[-10:]
# Out:
# Slowpoke                 1
# Mandibuzz                1
# Sableye                  1
# Murkrow                  1
# Mantyke                  1
# Rufflet                  1
# GourgeistAverage Size    1
# Hoppip                   1
# Gallade                  1
# Kyurem                   1
# Name: Name, dtype: int64

# %%
total_power[:20].plot(x='Name',kind='bar', figsize=(23,10))
